# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#   Using cached roboflow-1.1.47-py3-none-any.whl (80 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl (66 kB)
# ...
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="nncwJFLfgefHte4N9mkp")
project = rf.workspace("nycolasworkspace").project("csc-football-tracking-player")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to CSC-football-tracking-player-1 in yolov11:: 100%|██████████| 434/434 [00:00<00:00, 9946.77it/s]

# %%
# !yolo task=detect mode=train model=yolo11n.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 15.4MB/s]
# New https://pypi.org/project/ultralytics/8.3.9 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.8 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (12th Gen Intel Core(TM) i3-12100F)
# ...
